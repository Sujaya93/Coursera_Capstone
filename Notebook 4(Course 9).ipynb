# %% [markdown]
# #### First of all we import all the required libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Define Foursquare Credentials and Version by making Foursquare Account

# %%
CLIENT_ID = 'EU3R01YFQ5BAPLHSAKCAOCLQKTSTZHF425H42UJQX24E3EJO' # your Foursquare ID
CLIENT_SECRET = 'RIPVN1KONNUMXFSROXJZJ33J22FPFZF5DTPULPY0OUGYWUZ2' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: EU3R01YFQ5BAPLHSAKCAOCLQKTSTZHF425H42UJQX24E3EJO
# CLIENT_SECRET:RIPVN1KONNUMXFSROXJZJ33J22FPFZF5DTPULPY0OUGYWUZ2

# %% [markdown]
# #### Let's again assume that we are staying at the Plaza hotel. So let's start by converting the Plaza Hotel's address to its latitude and longitude coordinates.In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '768 5th Ave, New York, NY 10019'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7644819 -73.9744847382876

# %% [markdown]
#  Now, let's assume that it is lunch time, and we are craving for Indian food. So, let's define a query to search for restaurant
#  that is within 500 metres from the Plaza Hotel.

# %%
search_query = 'Indian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %% [markdown]
# #### Define the corresponding url

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EU3R01YFQ5BAPLHSAKCAOCLQKTSTZHF425H42UJQX24E3EJO&client_secret=RIPVN1KONNUMXFSROXJZJ33J22FPFZF5DTPULPY0OUGYWUZ2&ll=40.7644819,-73.9744847382876&v=20180604&query=Indian&radius=500&limit=30'

# %% [markdown]
# #### Send the get request and examine the results.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c5d5f30351e3d1dfae9a477'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '54135bf5e4b08f3d2429dfdd',
#       'name': 'North Indian Restaurant',
#       'pluralName': 'North Indian Restaurants',
#       'primary': True,
#       'shortName': 'North Indian'}],
#     'hasPerk': False,
#     'id': '56c55e43cd105142e6f95b94',
#     'location': {'address': '123 W 56th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 364,
#      'formattedAddress': ['123 W 56th St',
#       'New York, NY 10019',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76412724424148,
#        'lng': -73.97878651245028}],
#      'lat': 40.76412724424148,
#      'lng': -73.97878651245028,
#      'postalCode': '10019',
#      'state': 'NY'},
# ...

# %% [markdown]
#  #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'shortName': 'North Indian', 'pluralName': '...         NaN
# 1  [{'shortName': 'Office', 'pluralName': 'Office...         NaN
# 2  [{'shortName': 'Outdoor Sculpture', 'pluralNam...         NaN
# 3  [{'shortName': 'Indian', 'pluralName': 'Indian...      287683
# 4  [{'shortName': 'Indian', 'pluralName': 'Indian...         NaN
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3  /delivery_provider_seamless_20180129.png
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# ...

# %% [markdown]
# #### Define information of interest and filter dataframe.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                name               categories  \
# 0                     Indian Accent  North Indian Restaurant
# 1              Indian Country Today                   Office
# 2  LOVE Sculpture by Robert Indiana        Outdoor Sculpture
# 3                      Bengal Tiger        Indian Restaurant
# 4                             Sitar        Indian Restaurant
# 5        Consulate General of India      Embassy / Consulate
#
#                        address  cc      city        country  \
# 0                123 W 56th St  US  New York  United States
# 1        590 Madison Ave Fl 18  US  New York  United States
# 2  1350 Avenue of the Americas  US  New York  United States
# 3                 58 W 56th St  US  New York  United States
# 4                 58 W 56th St  US  New York  United States
# 5                  3 E 64th St  US  New York  United States
#
#           crossStreet  distance  \
# 0                 NaN       364
# 1         at 57th St.       294
# ...

# %% [markdown]
# #### Lets visualize the restaurants that are nearby.

# %%
dataframe_filtered.name
# Out:
# 0                       Indian Accent
# 1                Indian Country Today
# 2    LOVE Sculpture by Robert Indiana
# 3                        Bengal Tiger
# 4                               Sitar
# 5          Consulate General of India
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Plaza Hotel

# add a red circle marker to represent the Plaza Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Plaza Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Indian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,parse_html=True,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Now we explore a given venue.   A)Lets explore the closest restaurant.

# %%
#Lets explore closest restaurant Bengal Tiger Indian Food
venue_id = '526fe5de498e115999f8e9cc' # ID of Bengal Tiger Indian Food
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/526fe5de498e115999f8e9cc?client_id=EU3R01YFQ5BAPLHSAKCAOCLQKTSTZHF425H42UJQX24E3EJO&client_secret=RIPVN1KONNUMXFSROXJZJ33J22FPFZF5DTPULPY0OUGYWUZ2&v=20180604'

# %%
#Send get request for result

result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['ok', 'allowMenuUrlEdit', 'popular', 'specials', 'shortUrl', 'listed', 'reasons', 'hours', 'id', 'canonicalUrl', 'dislike', 'timeZone', 'pageUpdates', 'createdAt', 'ratingSignals', 'rating', 'price', 'verified', 'inbox', 'ratingColor', 'photos', 'categories', 'delivery', 'url', 'contact', 'tips', 'likes', 'bestPhoto', 'location', 'beenHere', 'hereNow', 'colors', 'attributes', 'name', 'stats'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}],
#     'name': 'Price',
#     'summary': '$',
#     'type': 'price'},
#    {'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'No'}],
#     'name': 'Reservations',
#     'type': 'reservations'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
# ...

# %% [markdown]
# #### B)Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %% [markdown]
# #### since this restaurant has a good rating we will explore it further.  C)Get the number of tips.

# %%
result['response']['venue']['tips']['count']
# Out:
# 75

# %% [markdown]
# #### D)Get the venue's tips.Next we create a URL and send GET request. We have to set limit to get all tips.

# %%
## Bengal Tiger Indian Food Tips
limit = 75 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c5d5f31dd57971929f39c48'},
#  'response': {'tips': {'count': 75,
#    'items': [{'agreeCount': 3,
#      'canonicalUrl': 'https://foursquare.com/item/5411e38c498ed2286e568ea2',
#      'createdAt': 1410458508,
#      'disagreeCount': 0,
#      'id': '5411e38c498ed2286e568ea2',
#      'lang': 'en',
#      'lastUpvoteTimestamp': 1547339738,
#      'lastVoteText': 'Upvoted 3 weeks ago',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'text': 'The pre-fixe meals are a huge amount of food for a reasonable price. Choice of soup or samosa, entree, rice and rice pudding for $15. If you add a garlic naan and you have a meal for two.',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Vincent',
#       'gender': 'male',
#       'id': '2009079',
#       'lastName': 'Cheung',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/X5YB4SSMTDT2YUXA.jpg'}}}]}}}

# %% [markdown]
# #### Then we get tips and list of associated features.

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['lastVoteText', 'disagreeCount', 'todo', 'lastUpvoteTimestamp', 'text', 'user', 'logView', 'id', 'canonicalUrl', 'type', 'lang', 'likes', 'createdAt', 'agreeCount'])

# %% [markdown]
# #### Next format column width and display all tips.

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                           text  \
# 0  The pre-fixe meals are a huge amount of food for a reasonable price. Choice of soup or samosa, entree, rice and rice pudding for $15. If you add a garlic naan and you have a meal for two.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  3           0              5411e38c498ed2286e568ea2  Vincent
#
#   user.lastName user.gender  user.id
# 0  Cheung        male        2009079

# %% [markdown]
# #### Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 75 tips.

# %% [markdown]
# #### 3. Search a Foursquare User
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# #### Define URL, send GET request and display features associated with user

# %%
user_id = '2009079' # user ID with most agree counts and complete profile
url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['checkins', 'lists', 'gender', 'friends', 'tips', 'lenses', 'firstName', 'photo', 'id', 'bio', 'canonicalUrl', 'type', 'lastName', 'mayorships', 'homeCity', 'contact', 'photos'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
# Out:
# First Name: Vincent
# Last Name: Cheung
# Home City: Hazlet, New Jersey

# %% [markdown]
# #### How many tips has this user submitted

# %%
user_data['tips']
# Out:
# {'count': 28}

# %% [markdown]
# So it turns out that Vincent has submitted 28 tips.

# %% [markdown]
# ### Get User's tips

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                                            text  \
# 0   The white gravy on the chicken sandwich is so good. The biscuit is also crumbly goodness. They also give you a beignet with your order.
# 1   All the drinks are great. I love the ability to customize your ice and sugar levels.
# 2   Not rice which is a cauliflower and brussel sprout mix that's cut so finely that it mimics a grain.
# 3   The original burger is good. The bacon avocado burger they only give you ONE small wedge of avocado. I also prefer the regular fries over the smash fries.
# 4   Free WiFi in the lobby. No login required.
# 5   If you're going to the second floor restaurant, just take the spiral staircase and avoid waiting for the elevator.
# 6   Get the mochi breaded fried chicken and the honey chips.
# ...

# %% [markdown]
# #### Let's get the venue for the tip with the greatest number of agree counts

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Cowgirl
# {'labeledLatLngs': [{'label': 'display', 'lat': 40.73373338282062, 'lng': -74.0062998849649}], 'country': 'United States', 'cc': 'US', 'formattedAddress': ['519 Hudson St (at W 10th St)', 'New York, NY 10014', 'United States'], 'address': '519 Hudson St', 'city': 'New York', 'crossStreet': 'at W 10th St', 'lng': -74.0062998849649, 'lat': 40.73373338282062, 'state': 'NY', 'postalCode': '10014'}

# %% [markdown]
# #### Get User's friends

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
#                          bio    firstName  gender  \
# 0  There is not enough time.  Naz          male
# 1                             Vanessa      female
# 2                             Richard      male
# 3                             Christine    female
# 4                             Tammy        female
# 5                             Christopher  male
# 6                             Justin       male
# 7                             Bo           male
# 8                             Joon         male
# 9                             S            female
#
#                                                        homeCity         id  \
# 0  Portland, OR                                                  579561
# 1  San Francisco                                                 21149051
# 2  New York, NY                                                  5873933
# 3  Phoenix, AZ                                                   8798431
# ...

# %% [markdown]
# We observe that Vincent Cheung has many friends.

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
user_data
# Out:
# {'bio': '',
#  'canonicalUrl': 'https://foursquare.com/hebiyo',
#  'checkins': {'count': 3338, 'items': []},
#  'contact': {},
#  'firstName': 'Vincent',
#  'friends': {'count': 197,
#   'groups': [{'count': 197,
#     'items': [{'bio': 'There is not enough time.',
#       'contact': {},
#       'firstName': 'Naz',
#       'gender': 'male',
#       'homeCity': 'Portland, OR',
#       'id': '579561',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/FVMIRSHJMXOTC02E.jpg'},
#       'tips': {'count': 0}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Vanessa',
#       'gender': 'female',
#       'homeCity': 'San Francisco',
#       'id': '21149051',
#       'lastName': 'Kwong',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
# ...

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# So, you just finished your meal at Bengal Tiger Indian Food, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Bengal Tiger Indian Food Restaurant.

# %%
latitude = 40.754280
longitude = -73.984871

# %% [markdown]
# #### Define url

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=EU3R01YFQ5BAPLHSAKCAOCLQKTSTZHF425H42UJQX24E3EJO&client_secret=RIPVN1KONNUMXFSROXJZJ33J22FPFZF5DTPULPY0OUGYWUZ2&ll=40.75428,-73.984871&v=20180604&radius=500&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests
results = requests.get(url).json()
'There are {} around Bengal Tiger Indian Food restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Bengal Tiger Indian Food restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-3fd66200f964a520d7f11ee3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d163941735',
#     'name': 'Park',
#     'pluralName': 'Parks',
#     'primary': True,
#     'shortName': 'Park'}],
#   'delivery': {'id': '298339',
#    'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#      'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50]},
#     'name': 'seamless'},
#    'url': 'https://www.seamless.com/menu/calle-dao-bryant-park-38-w-39th-st-new-york/298339?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=298339'},
#   'id': '3fd66200f964a520d7f11ee3',
#   'location': {'address': 'E 42nd St',
# ...

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe.

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(15)
# Out:
#                                   name           categories  \
# 0   Bryant Park                         Park
# 1   Books Kinokuniya                    Bookstore
# 2   sweetgreen                          Salad Place
# 3   Beautiful: The Carole King Musical  Theater
# 4   Joe's Pizza                         Pizza Place
# 5   Blue Bottle Coffee                  Coffee Shop
# 6   Gabriel Kreuther                    French Restaurant
# 7   Whole Foods Market                  Grocery Store
# 8   The Kati Roll Company               Indian Restaurant
# 9   OOTOYA 大戸屋 (OOTOYA)                 Japanese Restaurant
# 10  Equinox Bryant Park                 Gym
# 11  La Colombe Torrefaction             Coffee Shop
# 12  Stephen Sondheim Theatre            Theater
# 13  Bluestone Lane                      Coffee Shop
# 14  Koi New York                        Sushi Restaurant
#
#                         address  cc      city        country  \
# ...

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Bengal Tiger Indian Food


# add  Bengal Tiger Indian Food  as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Bengal Tiger Indian Food',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around Bengal Tiger Indian Food we are interested in knowing the venues that are trending at the time we are done with our lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Bengal Tiger Indian Food.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c5d5f34db04f57ab4cd788c'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'id': '5939022c6fa81f0e7aaa5797',
#     'location': {'address': '485 7th Avenue',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 442,
#      'formattedAddress': ['485 7th Avenue',
#       'New York, NY 10018',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75217,
#        'lng': -73.9893197}],
#      'lat': 40.75217,
#      'lng': -73.9893197,
#      'postalCode': '10018',
#      'state': 'NY'},
#     'name': 'MOXY NYC Times Square',
#     'venuePage': {'id': '443828321'}}]}}

# %% [markdown]
# #### Check if any values are trending at this time.

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
#                     name categories  location.distance location.city  \
# 0  MOXY NYC Times Square  Hotel      442                New York
#
#   location.postalCode location.state location.country  location.lat  \
# 0  10018               NY             United States    40.75217
#
#    location.lng
# 0 -73.98932

# %% [markdown]
# Now, depending on when we run the above code, we might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# #### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Bengal Tiger Indian Food


    # add Bengal Tiger Indian Food restaurant as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Bengal Tiger Indian Food',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
